# %% [markdown]
# **Modulo 3: TensorFlow y Keras para Neural Networks**
# * Instructor: [Juan Maniglia](https://juanmaniglia.github.io)

# %% [markdown]
# # Parte 3.4: Early Stopping en Keras para Prevenir Overfitting

# %% [markdown]
# **Overfitting** ocurre cuando una red neuronal se entrena hasta el punto de que comienza a memorizar en lugar de generalizar, como se muestra en la Figura 3.OVER.
#
# **Figure 3.OVER: Training vs Validation Error for Overfitting**
# ![Training vs Validation Error for Overfitting](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_3_training_val.png "Training vs Validation Error for Overfitting")
#
# Es importante segmentar el Dataset original en varios Datasets:
#
# * **Training Set**
# * **Validation Set**
# * **Holdout Set**
#
# Hay varias formas diferentes de construir estos conjuntos. Los siguientes programas demuestran algunos de estos.
#
# El primer método es un conjunto de entrenamiento y validación. Los datos de entrenamiento se utilizan para entrenar la red neuronal hasta que el conjunto de validación ya no mejora. Esto intenta detenerse en un punto de entrenamiento casi óptimo. Este método solo brindará predicciones precisas "fuera de la muestra" para el conjunto de validación, esto suele ser aproximadamente el 20 % de los datos. Las predicciones para los datos de entrenamiento serán demasiado optimistas, ya que estos fueron los datos con los que se entrenó la red neuronal. La Figura 3.VAL demuestra cómo se divide un conjunto de datos.
#
# **Figure 3.VAL: Training with a Validation Set**
# ![Training with a Validation Set](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_1_train_val.png "Training with a Validation Set")

# %% [markdown]
# ### Early Stopping con clasificación

# %%
import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris.csv", 
    na_values=['NA', '?'])

# Convertir a numpy - Clasificación
x = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Clasificación
species = dummies.columns
y = dummies.values

# Dividir en validation y training sets
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Construir la red neural
model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Oculta 1
model.add(Dense(25, activation='relu')) # Oculta 2
model.add(Dense(y.shape[1],activation='softmax')) # Salida
model.compile(loss='categorical_crossentropy', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, 
        verbose=1, mode='auto', restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor],verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 - 1s - loss: 1.8573 - val_loss: 1.5282 - 929ms/epoch - 232ms/step
# Epoch 2/1000
# 4/4 - 0s - loss: 1.5386 - val_loss: 1.3284 - 29ms/epoch - 7ms/step
# Epoch 3/1000
# 4/4 - 0s - loss: 1.3444 - val_loss: 1.2011 - 30ms/epoch - 7ms/step
# Epoch 4/1000
# 4/4 - 0s - loss: 1.2170 - val_loss: 1.1170 - 29ms/epoch - 7ms/step
# Epoch 5/1000
# 4/4 - 0s - loss: 1.1240 - val_loss: 1.0368 - 32ms/epoch - 8ms/step
# Epoch 6/1000
# 4/4 - 0s - loss: 1.0387 - val_loss: 0.9620 - 29ms/epoch - 7ms/step
# Epoch 7/1000
# 4/4 - 0s - loss: 0.9670 - val_loss: 0.8947 - 31ms/epoch - 8ms/step
# Epoch 8/1000
# 4/4 - 0s - loss: 0.9059 - val_loss: 0.8402 - 30ms/epoch - 7ms/step
# Epoch 9/1000
# 4/4 - 0s - loss: 0.8567 - val_loss: 0.7979 - 30ms/epoch - 7ms/step
# Epoch 10/1000
# 4/4 - 0s - loss: 0.8186 - val_loss: 0.7610 - 32ms/epoch - 8ms/step
# Epoch 11/1000
# 4/4 - 0s - loss: 0.7864 - val_loss: 0.7267 - 30ms/epoch - 8ms/step
# Epoch 12/1000
# 4/4 - 0s - loss: 0.7528 - val_loss: 0.6954 - 30ms/epoch - 8ms/step
# Epoch 13/1000
# 4/4 - 0s - loss: 0.7248 - val_loss: 0.6652 - 29ms/epoch - 7ms/step
# Epoch 14/1000
# 4/4 - 0s - loss: 0.6985 - val_loss: 0.6383 - 30ms/epoch - 8ms/step
# Epoch 15/1000
# 4/4 - 0s - loss: 0.6719 - val_loss: 0.6141 - 29ms/epoch - 7ms/step
# Epoch 16/1000
# 4/4 - 0s - loss: 0.6489 - val_loss: 0.5903 - 31ms/epoch - 8ms/step
# Epoch 17/1000
# 4/4 - 0s - loss: 0.6276 - val_loss: 0.5688 - 31ms/epoch - 8ms/step
# Epoch 18/1000
# 4/4 - 0s - loss: 0.6080 - val_loss: 0.5500 - 31ms/epoch - 8ms/step
# Epoch 19/1000
# 4/4 - 0s - loss: 0.5903 - val_loss: 0.5315 - 30ms/epoch - 8ms/step
# Epoch 20/1000
# 4/4 - 0s - loss: 0.5742 - val_loss: 0.5142 - 29ms/epoch - 7ms/step
# Epoch 21/1000
# 4/4 - 0s - loss: 0.5576 - val_loss: 0.4993 - 31ms/epoch - 8ms/step
# Epoch 22/1000
# 4/4 - 0s - loss: 0.5434 - val_loss: 0.4857 - 30ms/epoch - 8ms/step
# Epoch 23/1000
# 4/4 - 0s - loss: 0.5305 - val_loss: 0.4730 - 30ms/epoch - 8ms/step
# Epoch 24/1000
# 4/4 - 0s - loss: 0.5172 - val_loss: 0.4605 - 30ms/epoch - 8ms/step
# Epoch 25/1000
# 4/4 - 0s - loss: 0.5071 - val_loss: 0.4479 - 30ms/epoch - 8ms/step
# Epoch 26/1000
# 4/4 - 0s - loss: 0.4946 - val_loss: 0.4376 - 31ms/epoch - 8ms/step
# Epoch 27/1000
# 4/4 - 0s - loss: 0.4839 - val_loss: 0.4274 - 31ms/epoch - 8ms/step
# Epoch 28/1000
# 4/4 - 0s - loss: 0.4744 - val_loss: 0.4183 - 30ms/epoch - 7ms/step
# Epoch 29/1000
# 4/4 - 0s - loss: 0.4651 - val_loss: 0.4110 - 32ms/epoch - 8ms/step
# Epoch 30/1000
# 4/4 - 0s - loss: 0.4553 - val_loss: 0.4023 - 31ms/epoch - 8ms/step
# Epoch 31/1000
# 4/4 - 0s - loss: 0.4463 - val_loss: 0.3943 - 29ms/epoch - 7ms/step
# Epoch 32/1000
# 4/4 - 0s - loss: 0.4375 - val_loss: 0.3861 - 30ms/epoch - 8ms/step
# Epoch 33/1000
# 4/4 - 0s - loss: 0.4285 - val_loss: 0.3775 - 30ms/epoch - 8ms/step
# Epoch 34/1000
# 4/4 - 0s - loss: 0.4201 - val_loss: 0.3690 - 29ms/epoch - 7ms/step
# Epoch 35/1000
# 4/4 - 0s - loss: 0.4137 - val_loss: 0.3604 - 30ms/epoch - 8ms/step
# Epoch 36/1000
# 4/4 - 0s - loss: 0.4050 - val_loss: 0.3537 - 30ms/epoch - 8ms/step
# Epoch 37/1000
# 4/4 - 0s - loss: 0.3968 - val_loss: 0.3467 - 29ms/epoch - 7ms/step
# Epoch 38/1000
# 4/4 - 0s - loss: 0.3873 - val_loss: 0.3391 - 28ms/epoch - 7ms/step
# Epoch 39/1000
# 4/4 - 0s - loss: 0.3798 - val_loss: 0.3322 - 29ms/epoch - 7ms/step
# Epoch 40/1000
# 4/4 - 0s - loss: 0.3715 - val_loss: 0.3259 - 30ms/epoch - 8ms/step
# Epoch 41/1000
# 4/4 - 0s - loss: 0.3645 - val_loss: 0.3202 - 29ms/epoch - 7ms/step
# Epoch 42/1000
# 4/4 - 0s - loss: 0.3563 - val_loss: 0.3120 - 31ms/epoch - 8ms/step
# Epoch 43/1000
# 4/4 - 0s - loss: 0.3495 - val_loss: 0.3049 - 30ms/epoch - 8ms/step
# Epoch 44/1000
# 4/4 - 0s - loss: 0.3410 - val_loss: 0.2981 - 29ms/epoch - 7ms/step
# Epoch 45/1000
# 4/4 - 0s - loss: 0.3347 - val_loss: 0.2932 - 30ms/epoch - 7ms/step
# Epoch 46/1000
# 4/4 - 0s - loss: 0.3272 - val_loss: 0.2861 - 30ms/epoch - 7ms/step
# Epoch 47/1000
# 4/4 - 0s - loss: 0.3182 - val_loss: 0.2794 - 29ms/epoch - 7ms/step
# Epoch 48/1000
# 4/4 - 0s - loss: 0.3139 - val_loss: 0.2736 - 30ms/epoch - 8ms/step
# Epoch 49/1000
# 4/4 - 0s - loss: 0.3087 - val_loss: 0.2670 - 29ms/epoch - 7ms/step
# Epoch 50/1000
# 4/4 - 0s - loss: 0.2992 - val_loss: 0.2624 - 29ms/epoch - 7ms/step
# Epoch 51/1000
# 4/4 - 0s - loss: 0.2925 - val_loss: 0.2568 - 29ms/epoch - 7ms/step
# Epoch 52/1000
# 4/4 - 0s - loss: 0.2869 - val_loss: 0.2518 - 30ms/epoch - 7ms/step
# Epoch 53/1000
# 4/4 - 0s - loss: 0.2794 - val_loss: 0.2448 - 30ms/epoch - 8ms/step
# Epoch 54/1000
# 4/4 - 0s - loss: 0.2734 - val_loss: 0.2390 - 31ms/epoch - 8ms/step
# Epoch 55/1000
# 4/4 - 0s - loss: 0.2683 - val_loss: 0.2330 - 30ms/epoch - 8ms/step
# Epoch 56/1000
# 4/4 - 0s - loss: 0.2606 - val_loss: 0.2289 - 29ms/epoch - 7ms/step
# Epoch 57/1000
# 4/4 - 0s - loss: 0.2548 - val_loss: 0.2264 - 31ms/epoch - 8ms/step
# Epoch 58/1000
# 4/4 - 0s - loss: 0.2517 - val_loss: 0.2199 - 31ms/epoch - 8ms/step
# Epoch 59/1000
# 4/4 - 0s - loss: 0.2507 - val_loss: 0.2127 - 30ms/epoch - 8ms/step
# Epoch 60/1000
# 4/4 - 0s - loss: 0.2414 - val_loss: 0.2080 - 30ms/epoch - 7ms/step
# Epoch 61/1000
# 4/4 - 0s - loss: 0.2321 - val_loss: 0.2042 - 31ms/epoch - 8ms/step
# Epoch 62/1000
# 4/4 - 0s - loss: 0.2292 - val_loss: 0.2044 - 30ms/epoch - 7ms/step
# Epoch 63/1000
# 4/4 - 0s - loss: 0.2231 - val_loss: 0.1954 - 31ms/epoch - 8ms/step
# Epoch 64/1000
# 4/4 - 0s - loss: 0.2196 - val_loss: 0.1859 - 29ms/epoch - 7ms/step
# Epoch 65/1000
# 4/4 - 0s - loss: 0.2117 - val_loss: 0.1824 - 30ms/epoch - 7ms/step
# Epoch 66/1000
# 4/4 - 0s - loss: 0.2019 - val_loss: 0.1817 - 28ms/epoch - 7ms/step
# Epoch 67/1000
# 4/4 - 0s - loss: 0.1979 - val_loss: 0.1732 - 31ms/epoch - 8ms/step
# Epoch 68/1000
# 4/4 - 0s - loss: 0.1908 - val_loss: 0.1666 - 31ms/epoch - 8ms/step
# Epoch 69/1000
# 4/4 - 0s - loss: 0.1912 - val_loss: 0.1625 - 31ms/epoch - 8ms/step
# Epoch 70/1000
# 4/4 - 0s - loss: 0.1879 - val_loss: 0.1701 - 33ms/epoch - 8ms/step
# Epoch 71/1000
# 4/4 - 0s - loss: 0.1795 - val_loss: 0.1555 - 32ms/epoch - 8ms/step
# Epoch 72/1000
# 4/4 - 0s - loss: 0.1735 - val_loss: 0.1514 - 30ms/epoch - 8ms/step
# Epoch 73/1000
# 4/4 - 0s - loss: 0.1729 - val_loss: 0.1539 - 31ms/epoch - 8ms/step
# Epoch 74/1000
# 4/4 - 0s - loss: 0.1654 - val_loss: 0.1460 - 30ms/epoch - 7ms/step
# Epoch 75/1000
# 4/4 - 0s - loss: 0.1620 - val_loss: 0.1407 - 30ms/epoch - 8ms/step
# Epoch 76/1000
# 4/4 - 0s - loss: 0.1592 - val_loss: 0.1397 - 28ms/epoch - 7ms/step
# Epoch 77/1000
# 4/4 - 0s - loss: 0.1572 - val_loss: 0.1347 - 29ms/epoch - 7ms/step
# Epoch 78/1000
# 4/4 - 0s - loss: 0.1511 - val_loss: 0.1375 - 30ms/epoch - 8ms/step
# Epoch 79/1000
# 4/4 - 0s - loss: 0.1521 - val_loss: 0.1375 - 29ms/epoch - 7ms/step
# Epoch 80/1000
# 4/4 - 0s - loss: 0.1564 - val_loss: 0.1256 - 30ms/epoch - 8ms/step
# Epoch 81/1000
# 4/4 - 0s - loss: 0.1441 - val_loss: 0.1265 - 29ms/epoch - 7ms/step
# Epoch 82/1000
# 4/4 - 0s - loss: 0.1405 - val_loss: 0.1262 - 28ms/epoch - 7ms/step
# Epoch 83/1000
# 4/4 - 0s - loss: 0.1385 - val_loss: 0.1212 - 31ms/epoch - 8ms/step
# Epoch 84/1000
# 4/4 - 0s - loss: 0.1361 - val_loss: 0.1167 - 30ms/epoch - 7ms/step
# Epoch 85/1000
# 4/4 - 0s - loss: 0.1349 - val_loss: 0.1162 - 29ms/epoch - 7ms/step
# Epoch 86/1000
# 4/4 - 0s - loss: 0.1333 - val_loss: 0.1155 - 29ms/epoch - 7ms/step
# Epoch 87/1000
# 4/4 - 0s - loss: 0.1286 - val_loss: 0.1245 - 30ms/epoch - 8ms/step
# Epoch 88/1000
# 4/4 - 0s - loss: 0.1312 - val_loss: 0.1199 - 29ms/epoch - 7ms/step
# Epoch 89/1000
# 4/4 - 0s - loss: 0.1274 - val_loss: 0.1113 - 32ms/epoch - 8ms/step
# Epoch 90/1000
# 4/4 - 0s - loss: 0.1240 - val_loss: 0.1064 - 31ms/epoch - 8ms/step
# Epoch 91/1000
# 4/4 - 0s - loss: 0.1231 - val_loss: 0.1055 - 28ms/epoch - 7ms/step
# Epoch 92/1000
# 4/4 - 0s - loss: 0.1238 - val_loss: 0.1114 - 29ms/epoch - 7ms/step
# Epoch 93/1000
# 4/4 - 0s - loss: 0.1192 - val_loss: 0.1043 - 31ms/epoch - 8ms/step
# Epoch 94/1000
# 4/4 - 0s - loss: 0.1214 - val_loss: 0.0993 - 31ms/epoch - 8ms/step
# Epoch 95/1000
# 4/4 - 0s - loss: 0.1166 - val_loss: 0.1072 - 31ms/epoch - 8ms/step
# Epoch 96/1000
# 4/4 - 0s - loss: 0.1156 - val_loss: 0.1079 - 30ms/epoch - 7ms/step
# Epoch 97/1000
# 4/4 - 0s - loss: 0.1149 - val_loss: 0.1054 - 30ms/epoch - 8ms/step
# Epoch 98/1000
# 4/4 - 0s - loss: 0.1149 - val_loss: 0.0972 - 30ms/epoch - 8ms/step
# Epoch 99/1000
# 4/4 - 0s - loss: 0.1109 - val_loss: 0.1019 - 29ms/epoch - 7ms/step
# Epoch 100/1000
# 4/4 - 0s - loss: 0.1158 - val_loss: 0.1097 - 31ms/epoch - 8ms/step
# Epoch 101/1000
# 4/4 - 0s - loss: 0.1106 - val_loss: 0.0910 - 31ms/epoch - 8ms/step
# Epoch 102/1000
# 4/4 - 0s - loss: 0.1110 - val_loss: 0.0889 - 31ms/epoch - 8ms/step
# Epoch 103/1000
# 4/4 - 0s - loss: 0.1085 - val_loss: 0.0935 - 30ms/epoch - 8ms/step
# Epoch 104/1000
# 4/4 - 0s - loss: 0.1065 - val_loss: 0.0948 - 30ms/epoch - 8ms/step
# Epoch 105/1000
# 4/4 - 0s - loss: 0.1061 - val_loss: 0.1046 - 30ms/epoch - 7ms/step
# Epoch 106/1000
# 4/4 - 0s - loss: 0.1081 - val_loss: 0.0974 - 31ms/epoch - 8ms/step
# Epoch 107/1000
# 4/4 - 0s - loss: 0.1032 - val_loss: 0.0861 - 31ms/epoch - 8ms/step
# Epoch 108/1000
# 4/4 - 0s - loss: 0.1036 - val_loss: 0.0825 - 30ms/epoch - 8ms/step
# Epoch 109/1000
# 4/4 - 0s - loss: 0.1046 - val_loss: 0.0833 - 29ms/epoch - 7ms/step
# Epoch 110/1000
# 4/4 - 0s - loss: 0.1074 - val_loss: 0.0991 - 28ms/epoch - 7ms/step
# Epoch 111/1000
# 4/4 - 0s - loss: 0.1004 - val_loss: 0.0856 - 29ms/epoch - 7ms/step
# Epoch 112/1000
# 4/4 - 0s - loss: 0.0989 - val_loss: 0.0806 - 30ms/epoch - 7ms/step
# Epoch 113/1000
# 4/4 - 0s - loss: 0.0992 - val_loss: 0.0837 - 29ms/epoch - 7ms/step
# Epoch 114/1000
# 4/4 - 0s - loss: 0.0991 - val_loss: 0.0941 - 28ms/epoch - 7ms/step
# Epoch 115/1000
# 4/4 - 0s - loss: 0.0979 - val_loss: 0.0824 - 28ms/epoch - 7ms/step
# Epoch 116/1000
# 4/4 - 0s - loss: 0.0976 - val_loss: 0.0789 - 31ms/epoch - 8ms/step
# Epoch 117/1000
# 4/4 - 0s - loss: 0.0965 - val_loss: 0.0882 - 29ms/epoch - 7ms/step
# Epoch 118/1000
# 4/4 - 0s - loss: 0.0954 - val_loss: 0.0842 - 30ms/epoch - 8ms/step
# Epoch 119/1000
# 4/4 - 0s - loss: 0.0967 - val_loss: 0.0783 - 30ms/epoch - 8ms/step
# Epoch 120/1000
# 4/4 - 0s - loss: 0.0940 - val_loss: 0.0858 - 30ms/epoch - 8ms/step
# Epoch 121/1000
# Restoring model weights from the end of the best epoch: 116.
# 4/4 - 0s - loss: 0.0947 - val_loss: 0.0869 - 32ms/epoch - 8ms/step
# Epoch 00121: early stopping

# %% [markdown]
# Hay una serie de parámetros que se especifican para el objeto **EarlyStopping**.
#
# * **min_delta** Este valor debe mantenerse pequeño. Simplemente significa el cambio mínimo en error para ser registrado como una mejora. Configurarlo aún más pequeño probablemente no tendrá un gran impacto.
# * **patience** ¿Cuánto tiempo debe esperar el entrenamiento para que mejore el error de validación?
# * **verbose** ¿Cuánta información de progreso quieres?
# * **mode** En general, establezca siempre esto en "automático". Esto le permite especificar si el error debe minimizarse o maximizarse. Considere la precisión, donde se desean números más altos frente a log-loss/RMSE donde se desean números más bajos.
# * **restore_best_weights** Esto siempre debe establecerse en verdadero. Esto restaura los pesos a los valores que tenían cuando el conjunto de validación es el más alto. A menos que usted mismo realice un seguimiento manual de los pesos, debe hacer que Keras realice este paso por usted.
#
# Como puede ver desde arriba, no se utilizó el número total de épocas solicitadas. El entrenamiento de la red neuronal se detuvo una vez que el conjunto de validación dejó de mejorar.

# %%
from sklearn.metrics import accuracy_score

pred = model.predict(x_test)
predict_classes = np.argmax(pred,axis=1)
expected_classes = np.argmax(y_test,axis=1)
correct = accuracy_score(expected_classes,predict_classes)
print(f"Accuracy: {correct}")
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### Early Stopping con Regresión
#
# El siguiente código demuestra cómo podemos aplicar la detención anticipada a un problema de regresión. La técnica es similar a la detención anticipada del código de clasificación que acabamos de ver.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])

cars = df['name']

# tratado de missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas a Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regresión

# Dividir validation y training sets
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# construir la red neural
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Oculta 1
model.add(Dense(10, activation='relu')) # Oculta 2
model.add(Dense(1)) # Salida
model.compile(loss='mean_squared_error', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=5, verbose=1, mode='auto',
        restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor], verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 10/10 - 0s - loss: 908625.8125 - val_loss: 649708.1875 - 329ms/epoch - 33ms/step
# Epoch 2/1000
# 10/10 - 0s - loss: 522234.0938 - val_loss: 353329.7188 - 55ms/epoch - 5ms/step
# Epoch 3/1000
# 10/10 - 0s - loss: 281222.0000 - val_loss: 188052.2188 - 53ms/epoch - 5ms/step
# Epoch 4/1000
# 10/10 - 0s - loss: 147339.6094 - val_loss: 106029.1406 - 57ms/epoch - 6ms/step
# Epoch 5/1000
# 10/10 - 0s - loss: 92525.9531 - val_loss: 71449.0781 - 57ms/epoch - 6ms/step
# Epoch 6/1000
# 10/10 - 0s - loss: 61915.6562 - val_loss: 47527.8398 - 56ms/epoch - 6ms/step
# Epoch 7/1000
# 10/10 - 0s - loss: 41048.1680 - val_loss: 31603.6309 - 54ms/epoch - 5ms/step
# Epoch 8/1000
# 10/10 - 0s - loss: 27357.6367 - val_loss: 20776.6133 - 58ms/epoch - 6ms/step
# Epoch 9/1000
# 10/10 - 0s - loss: 17833.9199 - val_loss: 13464.7178 - 53ms/epoch - 5ms/step
# Epoch 10/1000
# 10/10 - 0s - loss: 11582.2871 - val_loss: 8414.0381 - 51ms/epoch - 5ms/step
# Epoch 11/1000
# 10/10 - 0s - loss: 7232.0874 - val_loss: 5146.3330 - 47ms/epoch - 5ms/step
# Epoch 12/1000
# 10/10 - 0s - loss: 4412.1807 - val_loss: 3083.8191 - 47ms/epoch - 5ms/step
# Epoch 13/1000
# 10/10 - 0s - loss: 2652.0276 - val_loss: 1840.1305 - 48ms/epoch - 5ms/step
# Epoch 14/1000
# 10/10 - 0s - loss: 1605.5598 - val_loss: 1088.1989 - 50ms/epoch - 5ms/step
# Epoch 15/1000
# 10/10 - 0s - loss: 977.6653 - val_loss: 652.7342 - 46ms/epoch - 5ms/step
# Epoch 16/1000
# 10/10 - 0s - loss: 613.6661 - val_loss: 409.2754 - 46ms/epoch - 5ms/step
# Epoch 17/1000
# 10/10 - 0s - loss: 408.2176 - val_loss: 285.5721 - 47ms/epoch - 5ms/step
# Epoch 18/1000
# 10/10 - 0s - loss: 299.7905 - val_loss: 221.9669 - 47ms/epoch - 5ms/step
# Epoch 19/1000
# 10/10 - 0s - loss: 238.3073 - val_loss: 184.9887 - 47ms/epoch - 5ms/step
# Epoch 20/1000
# 10/10 - 0s - loss: 199.7509 - val_loss: 158.9511 - 44ms/epoch - 4ms/step
# Epoch 21/1000
# 10/10 - 0s - loss: 170.2348 - val_loss: 141.7027 - 50ms/epoch - 5ms/step
# Epoch 22/1000
# 10/10 - 0s - loss: 151.3605 - val_loss: 128.8582 - 46ms/epoch - 5ms/step
# Epoch 23/1000
# 10/10 - 0s - loss: 138.2446 - val_loss: 120.1257 - 46ms/epoch - 5ms/step
# Epoch 24/1000
# 10/10 - 0s - loss: 129.3267 - val_loss: 115.4275 - 43ms/epoch - 4ms/step
# Epoch 25/1000
# 10/10 - 0s - loss: 124.5409 - val_loss: 113.1161 - 47ms/epoch - 5ms/step
# Epoch 26/1000
# 10/10 - 0s - loss: 121.8695 - val_loss: 111.9067 - 47ms/epoch - 5ms/step
# Epoch 27/1000
# 10/10 - 0s - loss: 120.6836 - val_loss: 111.2372 - 47ms/epoch - 5ms/step
# Epoch 28/1000
# 10/10 - 0s - loss: 119.9053 - val_loss: 110.6988 - 44ms/epoch - 4ms/step
# Epoch 29/1000
# 10/10 - 0s - loss: 119.3430 - val_loss: 110.2277 - 44ms/epoch - 4ms/step
# Epoch 30/1000
# 10/10 - 0s - loss: 118.9641 - val_loss: 109.9796 - 46ms/epoch - 5ms/step
# Epoch 31/1000
# 10/10 - 0s - loss: 118.6643 - val_loss: 109.7724 - 46ms/epoch - 5ms/step
# Epoch 32/1000
# 10/10 - 0s - loss: 118.4551 - val_loss: 109.6252 - 46ms/epoch - 5ms/step
# Epoch 33/1000
# 10/10 - 0s - loss: 118.2458 - val_loss: 109.5372 - 46ms/epoch - 5ms/step
# Epoch 34/1000
# 10/10 - 0s - loss: 118.0617 - val_loss: 109.4669 - 49ms/epoch - 5ms/step
# Epoch 35/1000
# 10/10 - 0s - loss: 117.9436 - val_loss: 109.3831 - 46ms/epoch - 5ms/step
# Epoch 36/1000
# 10/10 - 0s - loss: 117.7858 - val_loss: 109.2298 - 43ms/epoch - 4ms/step
# Epoch 37/1000
# 10/10 - 0s - loss: 117.6493 - val_loss: 109.0022 - 47ms/epoch - 5ms/step
# Epoch 38/1000
# 10/10 - 0s - loss: 117.5376 - val_loss: 108.8246 - 47ms/epoch - 5ms/step
# Epoch 39/1000
# 10/10 - 0s - loss: 117.4383 - val_loss: 108.6697 - 45ms/epoch - 4ms/step
# Epoch 40/1000
# 10/10 - 0s - loss: 117.3581 - val_loss: 108.5326 - 45ms/epoch - 4ms/step
# Epoch 41/1000
# 10/10 - 0s - loss: 117.2481 - val_loss: 108.4937 - 43ms/epoch - 4ms/step
# Epoch 42/1000
# 10/10 - 0s - loss: 117.1758 - val_loss: 108.4058 - 45ms/epoch - 5ms/step
# Epoch 43/1000
# 10/10 - 0s - loss: 117.1180 - val_loss: 108.3728 - 46ms/epoch - 5ms/step
# Epoch 44/1000
# 10/10 - 0s - loss: 117.0622 - val_loss: 108.3650 - 48ms/epoch - 5ms/step
# Epoch 45/1000
# 10/10 - 0s - loss: 117.0297 - val_loss: 108.3464 - 47ms/epoch - 5ms/step
# Epoch 46/1000
# 10/10 - 0s - loss: 116.9987 - val_loss: 108.2123 - 46ms/epoch - 5ms/step
# Epoch 47/1000
# 10/10 - 0s - loss: 116.9318 - val_loss: 108.1933 - 46ms/epoch - 5ms/step
# Epoch 48/1000
# 10/10 - 0s - loss: 116.8787 - val_loss: 108.1825 - 45ms/epoch - 4ms/step
# Epoch 49/1000
# 10/10 - 0s - loss: 116.8342 - val_loss: 108.1553 - 47ms/epoch - 5ms/step
# Epoch 50/1000
# 10/10 - 0s - loss: 116.7902 - val_loss: 108.0465 - 48ms/epoch - 5ms/step
# Epoch 51/1000
# 10/10 - 0s - loss: 116.7372 - val_loss: 107.9943 - 45ms/epoch - 5ms/step
# Epoch 52/1000
# 10/10 - 0s - loss: 116.6963 - val_loss: 107.9567 - 46ms/epoch - 5ms/step
# Epoch 53/1000
# 10/10 - 0s - loss: 116.6528 - val_loss: 107.8635 - 45ms/epoch - 5ms/step
# Epoch 54/1000
# 10/10 - 0s - loss: 116.6009 - val_loss: 107.8726 - 49ms/epoch - 5ms/step
# Epoch 55/1000
# 10/10 - 0s - loss: 116.5498 - val_loss: 107.8246 - 47ms/epoch - 5ms/step
# Epoch 56/1000
# 10/10 - 0s - loss: 116.5307 - val_loss: 107.6764 - 46ms/epoch - 5ms/step
# Epoch 57/1000
# 10/10 - 0s - loss: 116.4379 - val_loss: 107.6293 - 54ms/epoch - 5ms/step
# Epoch 58/1000
# 10/10 - 0s - loss: 116.3837 - val_loss: 107.5877 - 50ms/epoch - 5ms/step
# Epoch 59/1000
# 10/10 - 0s - loss: 116.3328 - val_loss: 107.5406 - 45ms/epoch - 4ms/step
# Epoch 60/1000
# 10/10 - 0s - loss: 116.2756 - val_loss: 107.5066 - 46ms/epoch - 5ms/step
# Epoch 61/1000
# 10/10 - 0s - loss: 116.2355 - val_loss: 107.4673 - 45ms/epoch - 5ms/step
# Epoch 62/1000
# 10/10 - 0s - loss: 116.1810 - val_loss: 107.3104 - 45ms/epoch - 4ms/step
# Epoch 63/1000
# 10/10 - 0s - loss: 116.1081 - val_loss: 107.2246 - 48ms/epoch - 5ms/step
# Epoch 64/1000
# 10/10 - 0s - loss: 116.0502 - val_loss: 107.1808 - 44ms/epoch - 4ms/step
# Epoch 65/1000
# 10/10 - 0s - loss: 116.0193 - val_loss: 107.1888 - 46ms/epoch - 5ms/step
# Epoch 66/1000
# 10/10 - 0s - loss: 115.9554 - val_loss: 107.0909 - 44ms/epoch - 4ms/step
# Epoch 67/1000
# 10/10 - 0s - loss: 115.9056 - val_loss: 107.0905 - 45ms/epoch - 5ms/step
# Epoch 68/1000
# 10/10 - 0s - loss: 115.8369 - val_loss: 107.0067 - 46ms/epoch - 5ms/step
# Epoch 69/1000
# 10/10 - 0s - loss: 115.7806 - val_loss: 106.9803 - 46ms/epoch - 5ms/step
# Epoch 70/1000
# 10/10 - 0s - loss: 115.7293 - val_loss: 106.9582 - 46ms/epoch - 5ms/step
# Epoch 71/1000
# 10/10 - 0s - loss: 115.7025 - val_loss: 106.8855 - 46ms/epoch - 5ms/step
# Epoch 72/1000
# 10/10 - 0s - loss: 115.6500 - val_loss: 106.7946 - 45ms/epoch - 5ms/step
# Epoch 73/1000
# 10/10 - 0s - loss: 115.5780 - val_loss: 106.8201 - 44ms/epoch - 4ms/step
# Epoch 74/1000
# 10/10 - 0s - loss: 115.5306 - val_loss: 106.8155 - 46ms/epoch - 5ms/step
# Epoch 75/1000
# 10/10 - 0s - loss: 115.4972 - val_loss: 106.8487 - 47ms/epoch - 5ms/step
# Epoch 76/1000
# 10/10 - 0s - loss: 115.4523 - val_loss: 106.8030 - 45ms/epoch - 4ms/step
# Epoch 77/1000
# 10/10 - 0s - loss: 115.4338 - val_loss: 106.5816 - 46ms/epoch - 5ms/step
# Epoch 78/1000
# 10/10 - 0s - loss: 115.3235 - val_loss: 106.5128 - 45ms/epoch - 4ms/step
# Epoch 79/1000
# 10/10 - 0s - loss: 115.2753 - val_loss: 106.4769 - 45ms/epoch - 4ms/step
# Epoch 80/1000
# 10/10 - 0s - loss: 115.2740 - val_loss: 106.5438 - 43ms/epoch - 4ms/step
# Epoch 81/1000
# 10/10 - 0s - loss: 115.1767 - val_loss: 106.4714 - 47ms/epoch - 5ms/step
# Epoch 82/1000
# 10/10 - 0s - loss: 115.1435 - val_loss: 106.4676 - 45ms/epoch - 5ms/step
# Epoch 83/1000
# 10/10 - 0s - loss: 115.0759 - val_loss: 106.3249 - 45ms/epoch - 5ms/step
# Epoch 84/1000
# 10/10 - 0s - loss: 115.0118 - val_loss: 106.2777 - 47ms/epoch - 5ms/step
# Epoch 85/1000
# 10/10 - 0s - loss: 114.9725 - val_loss: 106.2776 - 44ms/epoch - 4ms/step
# Epoch 86/1000
# 10/10 - 0s - loss: 114.9312 - val_loss: 106.1487 - 47ms/epoch - 5ms/step
# Epoch 87/1000
# 10/10 - 0s - loss: 114.8529 - val_loss: 106.1033 - 47ms/epoch - 5ms/step
# Epoch 88/1000
# 10/10 - 0s - loss: 114.8039 - val_loss: 105.9825 - 47ms/epoch - 5ms/step
# Epoch 89/1000
# 10/10 - 0s - loss: 114.7330 - val_loss: 105.8864 - 47ms/epoch - 5ms/step
# Epoch 90/1000
# 10/10 - 0s - loss: 114.6837 - val_loss: 105.8091 - 42ms/epoch - 4ms/step
# Epoch 91/1000
# 10/10 - 0s - loss: 114.6531 - val_loss: 105.6637 - 45ms/epoch - 4ms/step
# Epoch 92/1000
# 10/10 - 0s - loss: 114.5789 - val_loss: 105.6666 - 46ms/epoch - 5ms/step
# Epoch 93/1000
# 10/10 - 0s - loss: 114.5219 - val_loss: 105.6452 - 47ms/epoch - 5ms/step
# Epoch 94/1000
# 10/10 - 0s - loss: 114.4597 - val_loss: 105.6262 - 46ms/epoch - 5ms/step
# Epoch 95/1000
# 10/10 - 0s - loss: 114.4085 - val_loss: 105.6064 - 48ms/epoch - 5ms/step
# Epoch 96/1000
# 10/10 - 0s - loss: 114.3454 - val_loss: 105.4865 - 46ms/epoch - 5ms/step
# Epoch 97/1000
# 10/10 - 0s - loss: 114.3308 - val_loss: 105.2881 - 47ms/epoch - 5ms/step
# Epoch 98/1000
# 10/10 - 0s - loss: 114.2379 - val_loss: 105.2780 - 45ms/epoch - 4ms/step
# Epoch 99/1000
# 10/10 - 0s - loss: 114.2338 - val_loss: 105.0747 - 48ms/epoch - 5ms/step
# Epoch 100/1000
# 10/10 - 0s - loss: 114.1256 - val_loss: 105.0661 - 45ms/epoch - 5ms/step
# Epoch 101/1000
# 10/10 - 0s - loss: 114.0554 - val_loss: 104.9949 - 46ms/epoch - 5ms/step
# Epoch 102/1000
# 10/10 - 0s - loss: 114.0099 - val_loss: 104.9104 - 45ms/epoch - 4ms/step
# Epoch 103/1000
# 10/10 - 0s - loss: 113.9323 - val_loss: 104.8772 - 46ms/epoch - 5ms/step
# Epoch 104/1000
# 10/10 - 0s - loss: 113.8764 - val_loss: 104.8979 - 43ms/epoch - 4ms/step
# Epoch 105/1000
# 10/10 - 0s - loss: 113.8280 - val_loss: 104.9365 - 44ms/epoch - 4ms/step
# Epoch 106/1000
# 10/10 - 0s - loss: 113.7424 - val_loss: 104.8836 - 44ms/epoch - 4ms/step
# Epoch 107/1000
# 10/10 - 0s - loss: 113.6734 - val_loss: 104.7938 - 47ms/epoch - 5ms/step
# Epoch 108/1000
# 10/10 - 0s - loss: 113.6280 - val_loss: 104.7765 - 46ms/epoch - 5ms/step
# Epoch 109/1000
# 10/10 - 0s - loss: 113.6063 - val_loss: 104.5900 - 49ms/epoch - 5ms/step
# Epoch 110/1000
# 10/10 - 0s - loss: 113.5199 - val_loss: 104.7260 - 44ms/epoch - 4ms/step
# Epoch 111/1000
# 10/10 - 0s - loss: 113.4116 - val_loss: 104.6030 - 44ms/epoch - 4ms/step
# Epoch 112/1000
# 10/10 - 0s - loss: 113.3480 - val_loss: 104.4671 - 45ms/epoch - 5ms/step
# Epoch 113/1000
# 10/10 - 0s - loss: 113.3004 - val_loss: 104.3251 - 45ms/epoch - 5ms/step
# Epoch 114/1000
# 10/10 - 0s - loss: 113.2113 - val_loss: 104.2593 - 47ms/epoch - 5ms/step
# Epoch 115/1000
# 10/10 - 0s - loss: 113.1547 - val_loss: 104.2411 - 47ms/epoch - 5ms/step
# Epoch 116/1000
# 10/10 - 0s - loss: 113.0977 - val_loss: 104.1739 - 46ms/epoch - 5ms/step
# Epoch 117/1000
# 10/10 - 0s - loss: 113.0462 - val_loss: 104.0365 - 49ms/epoch - 5ms/step
# Epoch 118/1000
# 10/10 - 0s - loss: 112.9753 - val_loss: 104.0305 - 47ms/epoch - 5ms/step
# Epoch 119/1000
# 10/10 - 0s - loss: 112.8839 - val_loss: 103.9836 - 45ms/epoch - 5ms/step
# Epoch 120/1000
# 10/10 - 0s - loss: 112.8160 - val_loss: 103.8911 - 43ms/epoch - 4ms/step
# Epoch 121/1000
# 10/10 - 0s - loss: 112.7647 - val_loss: 103.8130 - 44ms/epoch - 4ms/step
# Epoch 122/1000
# 10/10 - 0s - loss: 112.7328 - val_loss: 103.6625 - 47ms/epoch - 5ms/step
# Epoch 123/1000
# 10/10 - 0s - loss: 112.6098 - val_loss: 103.6653 - 45ms/epoch - 4ms/step
# Epoch 124/1000
# 10/10 - 0s - loss: 112.5610 - val_loss: 103.6244 - 45ms/epoch - 5ms/step
# Epoch 125/1000
# 10/10 - 0s - loss: 112.4916 - val_loss: 103.6036 - 45ms/epoch - 5ms/step
# Epoch 126/1000
# 10/10 - 0s - loss: 112.4030 - val_loss: 103.4318 - 48ms/epoch - 5ms/step
# Epoch 127/1000
# 10/10 - 0s - loss: 112.3469 - val_loss: 103.2367 - 44ms/epoch - 4ms/step
# Epoch 128/1000
# 10/10 - 0s - loss: 112.2698 - val_loss: 103.2428 - 44ms/epoch - 4ms/step
# Epoch 129/1000
# 10/10 - 0s - loss: 112.1958 - val_loss: 103.2135 - 45ms/epoch - 5ms/step
# Epoch 130/1000
# 10/10 - 0s - loss: 112.1354 - val_loss: 103.1749 - 46ms/epoch - 5ms/step
# Epoch 131/1000
# 10/10 - 0s - loss: 112.0680 - val_loss: 103.1468 - 48ms/epoch - 5ms/step
# Epoch 132/1000
# 10/10 - 0s - loss: 111.9823 - val_loss: 103.0945 - 46ms/epoch - 5ms/step
# Epoch 133/1000
# 10/10 - 0s - loss: 111.9158 - val_loss: 103.1369 - 43ms/epoch - 4ms/step
# Epoch 134/1000
# 10/10 - 0s - loss: 111.8466 - val_loss: 103.0231 - 45ms/epoch - 5ms/step
# Epoch 135/1000
# 10/10 - 0s - loss: 111.7562 - val_loss: 102.8263 - 43ms/epoch - 4ms/step
# Epoch 136/1000
# 10/10 - 0s - loss: 111.7460 - val_loss: 102.6102 - 46ms/epoch - 5ms/step
# Epoch 137/1000
# 10/10 - 0s - loss: 111.6649 - val_loss: 102.4493 - 47ms/epoch - 5ms/step
# Epoch 138/1000
# 10/10 - 0s - loss: 111.5557 - val_loss: 102.4204 - 47ms/epoch - 5ms/step
# Epoch 139/1000
# 10/10 - 0s - loss: 111.4644 - val_loss: 102.3194 - 45ms/epoch - 5ms/step
# Epoch 140/1000
# 10/10 - 0s - loss: 111.3982 - val_loss: 102.2746 - 46ms/epoch - 5ms/step
# Epoch 141/1000
# 10/10 - 0s - loss: 111.3353 - val_loss: 102.1392 - 47ms/epoch - 5ms/step
# Epoch 142/1000
# 10/10 - 0s - loss: 111.2394 - val_loss: 102.0455 - 44ms/epoch - 4ms/step
# Epoch 143/1000
# 10/10 - 0s - loss: 111.1611 - val_loss: 101.9306 - 46ms/epoch - 5ms/step
# Epoch 144/1000
# 10/10 - 0s - loss: 111.0901 - val_loss: 101.8783 - 48ms/epoch - 5ms/step
# Epoch 145/1000
# 10/10 - 0s - loss: 111.0117 - val_loss: 101.8570 - 45ms/epoch - 5ms/step
# Epoch 146/1000
# 10/10 - 0s - loss: 110.9714 - val_loss: 101.7277 - 46ms/epoch - 5ms/step
# Epoch 147/1000
# 10/10 - 0s - loss: 110.8710 - val_loss: 101.5766 - 45ms/epoch - 4ms/step
# Epoch 148/1000
# 10/10 - 0s - loss: 110.7819 - val_loss: 101.6196 - 44ms/epoch - 4ms/step
# Epoch 149/1000
# 10/10 - 0s - loss: 110.7198 - val_loss: 101.6445 - 46ms/epoch - 5ms/step
# Epoch 150/1000
# 10/10 - 0s - loss: 110.6072 - val_loss: 101.5228 - 49ms/epoch - 5ms/step
# Epoch 151/1000
# 10/10 - 0s - loss: 110.5549 - val_loss: 101.3029 - 47ms/epoch - 5ms/step
# Epoch 152/1000
# 10/10 - 0s - loss: 110.5047 - val_loss: 101.1121 - 56ms/epoch - 6ms/step
# Epoch 153/1000
# 10/10 - 0s - loss: 110.3830 - val_loss: 101.0708 - 47ms/epoch - 5ms/step
# Epoch 154/1000
# 10/10 - 0s - loss: 110.3351 - val_loss: 101.2504 - 44ms/epoch - 4ms/step
# Epoch 155/1000
# 10/10 - 0s - loss: 110.1846 - val_loss: 101.2046 - 47ms/epoch - 5ms/step
# Epoch 156/1000
# 10/10 - 0s - loss: 110.1085 - val_loss: 101.0485 - 45ms/epoch - 5ms/step
# Epoch 157/1000
# 10/10 - 0s - loss: 110.0279 - val_loss: 100.8908 - 50ms/epoch - 5ms/step
# Epoch 158/1000
# 10/10 - 0s - loss: 109.9499 - val_loss: 100.9083 - 45ms/epoch - 5ms/step
# Epoch 159/1000
# 10/10 - 0s - loss: 109.8587 - val_loss: 100.9539 - 47ms/epoch - 5ms/step
# Epoch 160/1000
# 10/10 - 0s - loss: 109.7745 - val_loss: 100.8377 - 44ms/epoch - 4ms/step
# Epoch 161/1000
# 10/10 - 0s - loss: 109.6895 - val_loss: 100.7526 - 44ms/epoch - 4ms/step
# Epoch 162/1000
# 10/10 - 0s - loss: 109.6135 - val_loss: 100.8259 - 43ms/epoch - 4ms/step
# Epoch 163/1000
# 10/10 - 0s - loss: 109.5674 - val_loss: 100.7156 - 45ms/epoch - 5ms/step
# Epoch 164/1000
# 10/10 - 0s - loss: 109.4281 - val_loss: 100.4335 - 48ms/epoch - 5ms/step
# Epoch 165/1000
# 10/10 - 0s - loss: 109.2904 - val_loss: 100.1432 - 46ms/epoch - 5ms/step
# Epoch 166/1000
# 10/10 - 0s - loss: 109.3021 - val_loss: 99.9326 - 44ms/epoch - 4ms/step
# Epoch 167/1000
# 10/10 - 0s - loss: 109.2628 - val_loss: 99.7006 - 42ms/epoch - 4ms/step
# Epoch 168/1000
# 10/10 - 0s - loss: 109.1139 - val_loss: 99.6337 - 44ms/epoch - 4ms/step
# Epoch 169/1000
# 10/10 - 0s - loss: 109.1295 - val_loss: 99.6642 - 44ms/epoch - 4ms/step
# Epoch 170/1000
# 10/10 - 0s - loss: 108.9149 - val_loss: 99.4759 - 46ms/epoch - 5ms/step
# Epoch 171/1000
# 10/10 - 0s - loss: 108.8392 - val_loss: 99.3912 - 45ms/epoch - 5ms/step
# Epoch 172/1000
# 10/10 - 0s - loss: 108.7630 - val_loss: 99.2623 - 45ms/epoch - 5ms/step
# Epoch 173/1000
# 10/10 - 0s - loss: 108.6268 - val_loss: 99.3427 - 45ms/epoch - 5ms/step
# Epoch 174/1000
# 10/10 - 0s - loss: 108.5297 - val_loss: 99.3174 - 45ms/epoch - 5ms/step
# Epoch 175/1000
# 10/10 - 0s - loss: 108.5407 - val_loss: 99.4240 - 43ms/epoch - 4ms/step
# Epoch 176/1000
# 10/10 - 0s - loss: 108.3195 - val_loss: 99.1988 - 46ms/epoch - 5ms/step
# Epoch 177/1000
# 10/10 - 0s - loss: 108.2341 - val_loss: 99.0077 - 44ms/epoch - 4ms/step
# Epoch 178/1000
# 10/10 - 0s - loss: 108.1403 - val_loss: 98.8701 - 44ms/epoch - 4ms/step
# Epoch 179/1000
# 10/10 - 0s - loss: 108.0661 - val_loss: 98.7828 - 45ms/epoch - 5ms/step
# Epoch 180/1000
# 10/10 - 0s - loss: 107.9550 - val_loss: 98.7352 - 48ms/epoch - 5ms/step
# Epoch 181/1000
# 10/10 - 0s - loss: 107.8647 - val_loss: 98.6685 - 44ms/epoch - 4ms/step
# Epoch 182/1000
# 10/10 - 0s - loss: 107.7137 - val_loss: 98.8621 - 43ms/epoch - 4ms/step
# Epoch 183/1000
# 10/10 - 0s - loss: 107.6923 - val_loss: 98.9371 - 44ms/epoch - 4ms/step
# Epoch 184/1000
# 10/10 - 0s - loss: 107.6214 - val_loss: 98.9482 - 46ms/epoch - 5ms/step
# Epoch 185/1000
# 10/10 - 0s - loss: 107.5269 - val_loss: 98.8114 - 44ms/epoch - 4ms/step
# Epoch 186/1000
# 10/10 - 0s - loss: 107.4626 - val_loss: 98.3034 - 47ms/epoch - 5ms/step
# Epoch 187/1000
# 10/10 - 0s - loss: 107.2864 - val_loss: 97.9667 - 44ms/epoch - 4ms/step
# Epoch 188/1000
# 10/10 - 0s - loss: 107.2087 - val_loss: 97.9953 - 43ms/epoch - 4ms/step
# Epoch 189/1000
# 10/10 - 0s - loss: 107.0707 - val_loss: 97.8384 - 47ms/epoch - 5ms/step
# Epoch 190/1000
# 10/10 - 0s - loss: 106.9720 - val_loss: 97.7856 - 47ms/epoch - 5ms/step
# Epoch 191/1000
# 10/10 - 0s - loss: 106.9223 - val_loss: 97.8305 - 44ms/epoch - 4ms/step
# Epoch 192/1000
# 10/10 - 0s - loss: 106.8146 - val_loss: 97.4960 - 45ms/epoch - 5ms/step
# Epoch 193/1000
# 10/10 - 0s - loss: 106.7053 - val_loss: 97.2915 - 49ms/epoch - 5ms/step
# Epoch 194/1000
# 10/10 - 0s - loss: 106.6162 - val_loss: 97.3806 - 47ms/epoch - 5ms/step
# Epoch 195/1000
# 10/10 - 0s - loss: 106.4714 - val_loss: 97.1547 - 45ms/epoch - 5ms/step
# Epoch 196/1000
# 10/10 - 0s - loss: 106.3881 - val_loss: 97.0816 - 47ms/epoch - 5ms/step
# Epoch 197/1000
# 10/10 - 0s - loss: 106.2888 - val_loss: 96.7956 - 43ms/epoch - 4ms/step
# Epoch 198/1000
# 10/10 - 0s - loss: 106.1888 - val_loss: 96.7032 - 45ms/epoch - 5ms/step
# Epoch 199/1000
# 10/10 - 0s - loss: 106.1022 - val_loss: 96.5902 - 50ms/epoch - 5ms/step
# Epoch 200/1000
# 10/10 - 0s - loss: 105.9301 - val_loss: 96.6517 - 44ms/epoch - 4ms/step
# Epoch 201/1000
# 10/10 - 0s - loss: 105.8473 - val_loss: 96.7054 - 45ms/epoch - 4ms/step
# Epoch 202/1000
# 10/10 - 0s - loss: 105.7828 - val_loss: 96.6876 - 44ms/epoch - 4ms/step
# Epoch 203/1000
# 10/10 - 0s - loss: 105.6377 - val_loss: 96.5332 - 45ms/epoch - 5ms/step
# Epoch 204/1000
# 10/10 - 0s - loss: 105.5702 - val_loss: 96.2793 - 47ms/epoch - 5ms/step
# Epoch 205/1000
# 10/10 - 0s - loss: 105.4193 - val_loss: 96.2299 - 43ms/epoch - 4ms/step
# Epoch 206/1000
# 10/10 - 0s - loss: 105.3240 - val_loss: 96.1100 - 45ms/epoch - 4ms/step
# Epoch 207/1000
# 10/10 - 0s - loss: 105.2156 - val_loss: 95.7711 - 45ms/epoch - 5ms/step
# Epoch 208/1000
# 10/10 - 0s - loss: 105.1200 - val_loss: 95.6436 - 42ms/epoch - 4ms/step
# Epoch 209/1000
# 10/10 - 0s - loss: 105.0344 - val_loss: 95.3777 - 48ms/epoch - 5ms/step
# Epoch 210/1000
# 10/10 - 0s - loss: 104.9424 - val_loss: 95.3522 - 46ms/epoch - 5ms/step
# Epoch 211/1000
# 10/10 - 0s - loss: 104.8542 - val_loss: 95.5909 - 44ms/epoch - 4ms/step
# Epoch 212/1000
# 10/10 - 0s - loss: 104.6769 - val_loss: 95.4330 - 44ms/epoch - 4ms/step
# Epoch 213/1000
# 10/10 - 0s - loss: 104.5705 - val_loss: 95.4246 - 43ms/epoch - 4ms/step
# Epoch 214/1000
# 10/10 - 0s - loss: 104.4860 - val_loss: 95.4037 - 43ms/epoch - 4ms/step
# Epoch 215/1000
# 10/10 - 0s - loss: 104.3710 - val_loss: 95.1325 - 46ms/epoch - 5ms/step
# Epoch 216/1000
# 10/10 - 0s - loss: 104.2336 - val_loss: 95.1310 - 46ms/epoch - 5ms/step
# Epoch 217/1000
# 10/10 - 0s - loss: 104.1147 - val_loss: 95.0012 - 46ms/epoch - 5ms/step
# Epoch 218/1000
# 10/10 - 0s - loss: 103.9925 - val_loss: 94.7882 - 45ms/epoch - 5ms/step
# Epoch 219/1000
# 10/10 - 0s - loss: 103.8865 - val_loss: 94.4350 - 45ms/epoch - 5ms/step
# Epoch 220/1000
# 10/10 - 0s - loss: 103.8171 - val_loss: 94.1201 - 45ms/epoch - 5ms/step
# Epoch 221/1000
# 10/10 - 0s - loss: 103.7149 - val_loss: 93.9694 - 44ms/epoch - 4ms/step
# Epoch 222/1000
# 10/10 - 0s - loss: 103.6075 - val_loss: 93.9984 - 47ms/epoch - 5ms/step
# Epoch 223/1000
# 10/10 - 0s - loss: 103.4409 - val_loss: 93.9076 - 44ms/epoch - 4ms/step
# Epoch 224/1000
# 10/10 - 0s - loss: 103.3275 - val_loss: 93.8001 - 45ms/epoch - 5ms/step
# Epoch 225/1000
# 10/10 - 0s - loss: 103.2083 - val_loss: 93.5398 - 46ms/epoch - 5ms/step
# Epoch 226/1000
# 10/10 - 0s - loss: 103.1142 - val_loss: 93.6033 - 44ms/epoch - 4ms/step
# Epoch 227/1000
# 10/10 - 0s - loss: 102.9648 - val_loss: 93.5039 - 46ms/epoch - 5ms/step
# Epoch 228/1000
# 10/10 - 0s - loss: 102.9814 - val_loss: 93.6094 - 44ms/epoch - 4ms/step
# Epoch 229/1000
# 10/10 - 0s - loss: 102.7387 - val_loss: 93.4445 - 43ms/epoch - 4ms/step
# Epoch 230/1000
# 10/10 - 0s - loss: 102.6526 - val_loss: 93.3960 - 46ms/epoch - 5ms/step
# Epoch 231/1000
# 10/10 - 0s - loss: 102.4858 - val_loss: 93.1761 - 45ms/epoch - 5ms/step
# Epoch 232/1000
# 10/10 - 0s - loss: 102.3756 - val_loss: 93.1543 - 45ms/epoch - 5ms/step
# Epoch 233/1000
# 10/10 - 0s - loss: 102.2576 - val_loss: 92.9451 - 46ms/epoch - 5ms/step
# Epoch 234/1000
# 10/10 - 0s - loss: 102.1447 - val_loss: 92.9181 - 46ms/epoch - 5ms/step
# Epoch 235/1000
# 10/10 - 0s - loss: 102.0111 - val_loss: 93.0181 - 44ms/epoch - 4ms/step
# Epoch 236/1000
# 10/10 - 0s - loss: 101.9539 - val_loss: 93.0106 - 46ms/epoch - 5ms/step
# Epoch 237/1000
# 10/10 - 0s - loss: 101.9018 - val_loss: 92.5345 - 55ms/epoch - 6ms/step
# Epoch 238/1000
# 10/10 - 0s - loss: 101.6837 - val_loss: 92.3926 - 48ms/epoch - 5ms/step
# Epoch 239/1000
# 10/10 - 0s - loss: 101.5181 - val_loss: 92.3959 - 43ms/epoch - 4ms/step
# Epoch 240/1000
# 10/10 - 0s - loss: 101.4565 - val_loss: 92.1716 - 47ms/epoch - 5ms/step
# Epoch 241/1000
# 10/10 - 0s - loss: 101.2913 - val_loss: 92.0205 - 45ms/epoch - 5ms/step
# Epoch 242/1000
# 10/10 - 0s - loss: 101.1484 - val_loss: 91.7685 - 47ms/epoch - 5ms/step
# Epoch 243/1000
# 10/10 - 0s - loss: 101.1000 - val_loss: 91.4880 - 45ms/epoch - 5ms/step
# Epoch 244/1000
# 10/10 - 0s - loss: 100.9411 - val_loss: 91.3476 - 46ms/epoch - 5ms/step
# Epoch 245/1000
# 10/10 - 0s - loss: 100.8745 - val_loss: 91.3250 - 44ms/epoch - 4ms/step
# Epoch 246/1000
# 10/10 - 0s - loss: 100.6662 - val_loss: 91.0597 - 46ms/epoch - 5ms/step
# Epoch 247/1000
# 10/10 - 0s - loss: 100.7826 - val_loss: 90.6860 - 50ms/epoch - 5ms/step
# Epoch 248/1000
# 10/10 - 0s - loss: 100.4093 - val_loss: 90.8207 - 44ms/epoch - 4ms/step
# Epoch 249/1000
# 10/10 - 0s - loss: 100.4064 - val_loss: 91.1292 - 44ms/epoch - 4ms/step
# Epoch 250/1000
# 10/10 - 0s - loss: 100.1597 - val_loss: 90.8487 - 45ms/epoch - 4ms/step
# Epoch 251/1000
# 10/10 - 0s - loss: 100.0358 - val_loss: 90.6357 - 47ms/epoch - 5ms/step
# Epoch 252/1000
# 10/10 - 0s - loss: 99.9425 - val_loss: 90.5941 - 45ms/epoch - 4ms/step
# Epoch 253/1000
# 10/10 - 0s - loss: 99.7778 - val_loss: 90.3641 - 43ms/epoch - 4ms/step
# Epoch 254/1000
# 10/10 - 0s - loss: 99.6725 - val_loss: 90.1784 - 45ms/epoch - 5ms/step
# Epoch 255/1000
# 10/10 - 0s - loss: 99.5452 - val_loss: 90.1158 - 45ms/epoch - 5ms/step
# Epoch 256/1000
# 10/10 - 0s - loss: 99.4588 - val_loss: 90.3981 - 42ms/epoch - 4ms/step
# Epoch 257/1000
# 10/10 - 0s - loss: 99.3359 - val_loss: 90.3481 - 43ms/epoch - 4ms/step
# Epoch 258/1000
# 10/10 - 0s - loss: 99.1849 - val_loss: 90.0222 - 45ms/epoch - 5ms/step
# Epoch 259/1000
# 10/10 - 0s - loss: 99.1168 - val_loss: 89.5855 - 45ms/epoch - 5ms/step
# Epoch 260/1000
# 10/10 - 0s - loss: 98.8925 - val_loss: 89.3607 - 44ms/epoch - 4ms/step
# Epoch 261/1000
# 10/10 - 0s - loss: 98.7613 - val_loss: 89.3351 - 46ms/epoch - 5ms/step
# Epoch 262/1000
# 10/10 - 0s - loss: 98.6209 - val_loss: 89.2172 - 46ms/epoch - 5ms/step
# Epoch 263/1000
# 10/10 - 0s - loss: 98.5625 - val_loss: 89.2766 - 45ms/epoch - 5ms/step
# Epoch 264/1000
# 10/10 - 0s - loss: 98.4003 - val_loss: 89.0602 - 46ms/epoch - 5ms/step
# Epoch 265/1000
# 10/10 - 0s - loss: 98.2448 - val_loss: 88.8687 - 46ms/epoch - 5ms/step
# Epoch 266/1000
# 10/10 - 0s - loss: 98.1143 - val_loss: 88.6921 - 47ms/epoch - 5ms/step
# Epoch 267/1000
# 10/10 - 0s - loss: 98.0451 - val_loss: 88.1388 - 47ms/epoch - 5ms/step
# Epoch 268/1000
# 10/10 - 0s - loss: 97.8720 - val_loss: 87.9945 - 44ms/epoch - 4ms/step
# Epoch 269/1000
# 10/10 - 0s - loss: 97.7326 - val_loss: 88.2156 - 44ms/epoch - 4ms/step
# Epoch 270/1000
# 10/10 - 0s - loss: 97.5796 - val_loss: 87.9659 - 44ms/epoch - 4ms/step
# Epoch 271/1000
# 10/10 - 0s - loss: 97.4003 - val_loss: 87.9199 - 45ms/epoch - 4ms/step
# Epoch 272/1000
# 10/10 - 0s - loss: 97.2586 - val_loss: 87.6531 - 48ms/epoch - 5ms/step
# Epoch 273/1000
# 10/10 - 0s - loss: 97.1383 - val_loss: 87.6808 - 47ms/epoch - 5ms/step
# Epoch 274/1000
# 10/10 - 0s - loss: 97.1311 - val_loss: 87.2834 - 47ms/epoch - 5ms/step
# Epoch 275/1000
# 10/10 - 0s - loss: 96.7964 - val_loss: 87.4493 - 45ms/epoch - 5ms/step
# Epoch 276/1000
# 10/10 - 0s - loss: 96.7223 - val_loss: 87.2553 - 45ms/epoch - 5ms/step
# Epoch 277/1000
# 10/10 - 0s - loss: 96.5998 - val_loss: 86.8418 - 44ms/epoch - 4ms/step
# Epoch 278/1000
# 10/10 - 0s - loss: 96.4598 - val_loss: 86.8623 - 45ms/epoch - 5ms/step
# Epoch 279/1000
# 10/10 - 0s - loss: 96.2662 - val_loss: 86.8508 - 45ms/epoch - 5ms/step
# Epoch 280/1000
# 10/10 - 0s - loss: 96.1435 - val_loss: 86.6889 - 46ms/epoch - 5ms/step
# Epoch 281/1000
# 10/10 - 0s - loss: 96.0404 - val_loss: 86.4361 - 44ms/epoch - 4ms/step
# Epoch 282/1000
# 10/10 - 0s - loss: 95.8639 - val_loss: 86.1866 - 45ms/epoch - 5ms/step
# Epoch 283/1000
# 10/10 - 0s - loss: 95.7551 - val_loss: 86.0842 - 45ms/epoch - 5ms/step
# Epoch 284/1000
# 10/10 - 0s - loss: 95.6374 - val_loss: 85.9447 - 45ms/epoch - 4ms/step
# Epoch 285/1000
# 10/10 - 0s - loss: 95.4297 - val_loss: 85.7694 - 44ms/epoch - 4ms/step
# Epoch 286/1000
# 10/10 - 0s - loss: 95.2858 - val_loss: 85.6647 - 45ms/epoch - 5ms/step
# Epoch 287/1000
# 10/10 - 0s - loss: 95.1406 - val_loss: 85.5740 - 43ms/epoch - 4ms/step
# Epoch 288/1000
# 10/10 - 0s - loss: 95.0278 - val_loss: 85.7122 - 42ms/epoch - 4ms/step
# Epoch 289/1000
# 10/10 - 0s - loss: 94.8696 - val_loss: 85.5555 - 46ms/epoch - 5ms/step
# Epoch 290/1000
# 10/10 - 0s - loss: 94.6809 - val_loss: 84.8388 - 45ms/epoch - 5ms/step
# Epoch 291/1000
# 10/10 - 0s - loss: 94.5919 - val_loss: 84.6897 - 45ms/epoch - 5ms/step
# Epoch 292/1000
# 10/10 - 0s - loss: 94.4493 - val_loss: 84.4943 - 45ms/epoch - 5ms/step
# Epoch 293/1000
# 10/10 - 0s - loss: 94.2753 - val_loss: 84.4434 - 45ms/epoch - 5ms/step
# Epoch 294/1000
# 10/10 - 0s - loss: 94.1471 - val_loss: 84.3596 - 46ms/epoch - 5ms/step
# Epoch 295/1000
# 10/10 - 0s - loss: 93.9946 - val_loss: 84.5849 - 43ms/epoch - 4ms/step
# Epoch 296/1000
# 10/10 - 0s - loss: 93.8836 - val_loss: 84.5781 - 45ms/epoch - 5ms/step
# Epoch 297/1000
# 10/10 - 0s - loss: 93.6674 - val_loss: 84.3381 - 45ms/epoch - 5ms/step
# Epoch 298/1000
# 10/10 - 0s - loss: 93.4931 - val_loss: 83.8886 - 46ms/epoch - 5ms/step
# Epoch 299/1000
# 10/10 - 0s - loss: 93.3681 - val_loss: 83.7572 - 45ms/epoch - 4ms/step
# Epoch 300/1000
# 10/10 - 0s - loss: 93.1981 - val_loss: 83.9509 - 44ms/epoch - 4ms/step
# Epoch 301/1000
# 10/10 - 0s - loss: 93.0817 - val_loss: 83.7717 - 43ms/epoch - 4ms/step
# Epoch 302/1000
# 10/10 - 0s - loss: 92.9128 - val_loss: 83.6001 - 46ms/epoch - 5ms/step
# Epoch 303/1000
# 10/10 - 0s - loss: 92.7436 - val_loss: 83.2618 - 45ms/epoch - 5ms/step
# Epoch 304/1000
# 10/10 - 0s - loss: 92.6061 - val_loss: 82.9047 - 46ms/epoch - 5ms/step
# Epoch 305/1000
# 10/10 - 0s - loss: 92.4463 - val_loss: 82.6801 - 50ms/epoch - 5ms/step
# Epoch 306/1000
# 10/10 - 0s - loss: 92.2702 - val_loss: 82.8295 - 44ms/epoch - 4ms/step
# Epoch 307/1000
# 10/10 - 0s - loss: 92.2105 - val_loss: 83.0990 - 46ms/epoch - 5ms/step
# Epoch 308/1000
# 10/10 - 0s - loss: 91.9672 - val_loss: 82.4571 - 49ms/epoch - 5ms/step
# Epoch 309/1000
# 10/10 - 0s - loss: 91.8080 - val_loss: 82.2301 - 48ms/epoch - 5ms/step
# Epoch 310/1000
# 10/10 - 0s - loss: 91.6664 - val_loss: 82.0173 - 46ms/epoch - 5ms/step
# Epoch 311/1000
# 10/10 - 0s - loss: 91.4468 - val_loss: 82.2696 - 45ms/epoch - 4ms/step
# Epoch 312/1000
# 10/10 - 0s - loss: 91.3206 - val_loss: 81.9862 - 46ms/epoch - 5ms/step
# Epoch 313/1000
# 10/10 - 0s - loss: 91.1469 - val_loss: 82.0110 - 43ms/epoch - 4ms/step
# Epoch 314/1000
# 10/10 - 0s - loss: 91.0001 - val_loss: 81.8418 - 45ms/epoch - 5ms/step
# Epoch 315/1000
# 10/10 - 0s - loss: 90.8687 - val_loss: 81.7689 - 45ms/epoch - 5ms/step
# Epoch 316/1000
# 10/10 - 0s - loss: 90.6795 - val_loss: 81.9570 - 45ms/epoch - 5ms/step
# Epoch 317/1000
# 10/10 - 0s - loss: 90.7146 - val_loss: 82.1438 - 45ms/epoch - 5ms/step
# Epoch 318/1000
# 10/10 - 0s - loss: 90.5475 - val_loss: 80.7980 - 45ms/epoch - 5ms/step
# Epoch 319/1000
# 10/10 - 0s - loss: 90.1704 - val_loss: 80.6465 - 45ms/epoch - 5ms/step
# Epoch 320/1000
# 10/10 - 0s - loss: 90.0750 - val_loss: 80.5699 - 47ms/epoch - 5ms/step
# Epoch 321/1000
# 10/10 - 0s - loss: 89.8491 - val_loss: 80.3877 - 47ms/epoch - 5ms/step
# Epoch 322/1000
# 10/10 - 0s - loss: 89.7129 - val_loss: 80.1897 - 46ms/epoch - 5ms/step
# Epoch 323/1000
# 10/10 - 0s - loss: 89.5530 - val_loss: 80.1348 - 45ms/epoch - 5ms/step
# Epoch 324/1000
# 10/10 - 0s - loss: 89.4130 - val_loss: 80.4340 - 45ms/epoch - 5ms/step
# Epoch 325/1000
# 10/10 - 0s - loss: 89.2423 - val_loss: 79.8607 - 45ms/epoch - 5ms/step
# Epoch 326/1000
# 10/10 - 0s - loss: 89.0852 - val_loss: 79.7973 - 45ms/epoch - 4ms/step
# Epoch 327/1000
# 10/10 - 0s - loss: 88.9010 - val_loss: 79.5547 - 52ms/epoch - 5ms/step
# Epoch 328/1000
# 10/10 - 0s - loss: 88.7232 - val_loss: 79.0892 - 43ms/epoch - 4ms/step
# Epoch 329/1000
# 10/10 - 0s - loss: 88.5475 - val_loss: 78.7168 - 46ms/epoch - 5ms/step
# Epoch 330/1000
# 10/10 - 0s - loss: 88.3959 - val_loss: 78.6512 - 45ms/epoch - 5ms/step
# Epoch 331/1000
# 10/10 - 0s - loss: 88.2274 - val_loss: 78.8935 - 46ms/epoch - 5ms/step
# Epoch 332/1000
# 10/10 - 0s - loss: 88.0785 - val_loss: 78.2338 - 43ms/epoch - 4ms/step
# Epoch 333/1000
# 10/10 - 0s - loss: 87.8690 - val_loss: 78.2261 - 45ms/epoch - 5ms/step
# Epoch 334/1000
# 10/10 - 0s - loss: 87.7029 - val_loss: 78.1526 - 45ms/epoch - 5ms/step
# Epoch 335/1000
# 10/10 - 0s - loss: 87.5074 - val_loss: 77.9174 - 46ms/epoch - 5ms/step
# Epoch 336/1000
# 10/10 - 0s - loss: 87.4142 - val_loss: 77.5248 - 45ms/epoch - 4ms/step
# Epoch 337/1000
# 10/10 - 0s - loss: 87.2105 - val_loss: 77.5059 - 47ms/epoch - 5ms/step
# Epoch 338/1000
# 10/10 - 0s - loss: 87.0368 - val_loss: 78.0792 - 43ms/epoch - 4ms/step
# Epoch 339/1000
# 10/10 - 0s - loss: 86.9123 - val_loss: 78.0992 - 44ms/epoch - 4ms/step
# Epoch 340/1000
# 10/10 - 0s - loss: 86.7185 - val_loss: 77.6906 - 44ms/epoch - 4ms/step
# Epoch 341/1000
# 10/10 - 0s - loss: 86.5990 - val_loss: 77.5388 - 50ms/epoch - 5ms/step
# Epoch 342/1000
# 10/10 - 0s - loss: 86.3093 - val_loss: 76.9670 - 47ms/epoch - 5ms/step
# Epoch 343/1000
# 10/10 - 0s - loss: 86.1366 - val_loss: 76.6330 - 45ms/epoch - 5ms/step
# Epoch 344/1000
# 10/10 - 0s - loss: 85.9993 - val_loss: 76.1920 - 47ms/epoch - 5ms/step
# Epoch 345/1000
# 10/10 - 0s - loss: 85.8575 - val_loss: 76.1810 - 47ms/epoch - 5ms/step
# Epoch 346/1000
# 10/10 - 0s - loss: 85.6613 - val_loss: 76.1834 - 45ms/epoch - 4ms/step
# Epoch 347/1000
# 10/10 - 0s - loss: 85.6105 - val_loss: 76.7434 - 45ms/epoch - 5ms/step
# Epoch 348/1000
# 10/10 - 0s - loss: 85.3844 - val_loss: 76.4996 - 45ms/epoch - 5ms/step
# Epoch 349/1000
# 10/10 - 0s - loss: 85.5631 - val_loss: 75.2879 - 47ms/epoch - 5ms/step
# Epoch 350/1000
# 10/10 - 0s - loss: 84.9404 - val_loss: 75.6278 - 44ms/epoch - 4ms/step
# Epoch 351/1000
# 10/10 - 0s - loss: 84.8858 - val_loss: 76.0460 - 42ms/epoch - 4ms/step
# Epoch 352/1000
# 10/10 - 0s - loss: 84.6398 - val_loss: 75.8067 - 46ms/epoch - 5ms/step
# Epoch 353/1000
# 10/10 - 0s - loss: 84.4997 - val_loss: 75.3179 - 43ms/epoch - 4ms/step
# Epoch 354/1000
# 10/10 - 0s - loss: 84.3335 - val_loss: 74.7520 - 49ms/epoch - 5ms/step
# Epoch 355/1000
# 10/10 - 0s - loss: 82.9951 - val_loss: 63.5485 - 48ms/epoch - 5ms/step
# Epoch 356/1000
# 10/10 - 0s - loss: 62.0072 - val_loss: 53.3225 - 47ms/epoch - 5ms/step
# Epoch 357/1000
# 10/10 - 0s - loss: 59.0142 - val_loss: 49.2159 - 49ms/epoch - 5ms/step
# Epoch 358/1000
# 10/10 - 0s - loss: 54.5920 - val_loss: 50.6872 - 47ms/epoch - 5ms/step
# Epoch 359/1000
# 10/10 - 0s - loss: 60.6727 - val_loss: 55.8601 - 46ms/epoch - 5ms/step
# Epoch 360/1000
# 10/10 - 0s - loss: 59.6471 - val_loss: 50.6585 - 49ms/epoch - 5ms/step
# Epoch 361/1000
# 10/10 - 0s - loss: 54.3630 - val_loss: 48.6406 - 49ms/epoch - 5ms/step
# Epoch 362/1000
# 10/10 - 0s - loss: 53.4314 - val_loss: 56.3757 - 46ms/epoch - 5ms/step
# Epoch 363/1000
# 10/10 - 0s - loss: 53.4520 - val_loss: 48.4645 - 45ms/epoch - 5ms/step
# Epoch 364/1000
# 10/10 - 0s - loss: 51.2224 - val_loss: 50.8076 - 45ms/epoch - 5ms/step
# Epoch 365/1000
# 10/10 - 0s - loss: 53.0812 - val_loss: 53.4662 - 48ms/epoch - 5ms/step
# Epoch 366/1000
# 10/10 - 0s - loss: 51.8595 - val_loss: 50.3704 - 47ms/epoch - 5ms/step
# Epoch 367/1000
# 10/10 - 0s - loss: 49.8131 - val_loss: 48.2039 - 50ms/epoch - 5ms/step
# Epoch 368/1000
# 10/10 - 0s - loss: 48.8157 - val_loss: 46.3751 - 46ms/epoch - 5ms/step
# Epoch 369/1000
# 10/10 - 0s - loss: 48.7779 - val_loss: 45.7344 - 44ms/epoch - 4ms/step
# Epoch 370/1000
# 10/10 - 0s - loss: 49.2765 - val_loss: 55.7113 - 46ms/epoch - 5ms/step
# Epoch 371/1000
# 10/10 - 0s - loss: 51.3751 - val_loss: 46.4953 - 47ms/epoch - 5ms/step
# Epoch 372/1000
# 10/10 - 0s - loss: 47.5421 - val_loss: 45.3122 - 46ms/epoch - 5ms/step
# Epoch 373/1000
# 10/10 - 0s - loss: 48.1340 - val_loss: 46.4456 - 42ms/epoch - 4ms/step
# Epoch 374/1000
# 10/10 - 0s - loss: 47.8897 - val_loss: 45.2854 - 44ms/epoch - 4ms/step
# Epoch 375/1000
# 10/10 - 0s - loss: 46.6883 - val_loss: 46.2650 - 45ms/epoch - 5ms/step
# Epoch 376/1000
# 10/10 - 0s - loss: 46.6642 - val_loss: 44.2102 - 45ms/epoch - 5ms/step
# Epoch 377/1000
# 10/10 - 0s - loss: 46.2449 - val_loss: 44.8760 - 42ms/epoch - 4ms/step
# Epoch 378/1000
# 10/10 - 0s - loss: 45.9095 - val_loss: 44.8402 - 44ms/epoch - 4ms/step
# Epoch 379/1000
# 10/10 - 0s - loss: 46.1142 - val_loss: 45.0765 - 43ms/epoch - 4ms/step
# Epoch 380/1000
# 10/10 - 0s - loss: 45.1346 - val_loss: 47.8484 - 45ms/epoch - 5ms/step
# Epoch 381/1000
# Restoring model weights from the end of the best epoch: 376.
# 10/10 - 0s - loss: 45.8130 - val_loss: 44.7479 - 46ms/epoch - 5ms/step
# Epoch 00381: early stopping

# %% [markdown]
# Finalmente, evaluamos el error.

# %%
#RMSE error.
pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print(f"Final score (RMSE): {score}")
# Out:
# Final score (RMSE): 6.6490729876769255
