# %% [markdown]
# **Modulo 3: TensorFlow y Keras para Neural Networks**
# * Instructor: [Juan Maniglia](https://juanmaniglia.github.io)

# %% [markdown]
# # Parte 3.3: Guardar y cargar una red neuronal de Keras
#
# Las redes neuronales complejas tardarán mucho tiempo en adaptarse/entrenarse. Es útil poder guardar estas redes neuronales para que puedan recargarse más tarde. Una red neuronal recargada no requerirá un nuevo entrenamiento. Keras proporciona tres formatos para guardar redes neuronales.
#
# * **YAML** - Almacena la estructura de la red neuronal (sin pesos) en el [YAML file format](https://en.wikipedia.org/wiki/YAML).
# * **JSON** - Almacena la estructura de la red neuronal (sin pesos) en el [JSON file format](https://en.wikipedia.org/wiki/JSON).
# * **HDF5** - Almacena la red neuronal completa (con pesos) en el [HDF5 file format](https://en.wikipedia.org/wiki/Hierarchical_Data_Format). No confunda HDF5 con [HDFS](https://en.wikipedia.org/wiki/Apache_Hadoop).
#
# Por lo general, querrá guardar en HDF5.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

save_path = "."

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])

cars = df['name']

# Tratado de missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas a Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regresión

# construcción de la neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Oculta 1
model.add(Dense(10, activation='relu')) # Oculta 2
model.add(Dense(1)) # Salida
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x,y,verbose=2,epochs=100)

# Predict
pred = model.predict(x)

# RMSE error.  
score = np.sqrt(metrics.mean_squared_error(pred,y))
print(f"Antes de Guardar el (RMSE): {score}")

# guardar la estructura de la red neuronal en JSON (sin weights)
model_json = model.to_json()
with open(os.path.join(save_path,"network.json"), "w") as json_file:
    json_file.write(model_json)

# guardar toda la red en HDF5 (guardar todo es lo recomendado)
model.save(os.path.join(save_path,"network.h5"))
# Out:
# Epoch 1/100
# 13/13 - 0s - loss: 204515.2344 - 245ms/epoch - 19ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 7687.1880 - 37ms/epoch - 3ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 11632.9727 - 34ms/epoch - 3ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 1722.8514 - 33ms/epoch - 3ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 1582.1915 - 34ms/epoch - 3ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 910.1257 - 33ms/epoch - 3ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 852.8941 - 32ms/epoch - 2ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 787.2728 - 36ms/epoch - 3ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 749.2866 - 33ms/epoch - 3ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 687.3815 - 31ms/epoch - 2ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 641.3677 - 32ms/epoch - 2ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 596.4457 - 31ms/epoch - 2ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 553.3340 - 31ms/epoch - 2ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 500.1074 - 32ms/epoch - 2ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 460.6832 - 30ms/epoch - 2ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 407.5528 - 32ms/epoch - 2ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 361.2777 - 30ms/epoch - 2ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 318.3586 - 31ms/epoch - 2ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 275.8819 - 29ms/epoch - 2ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 237.6320 - 26ms/epoch - 2ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 203.4184 - 26ms/epoch - 2ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 173.0200 - 25ms/epoch - 2ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 149.1206 - 26ms/epoch - 2ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 126.2231 - 25ms/epoch - 2ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 105.0082 - 26ms/epoch - 2ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 91.4845 - 27ms/epoch - 2ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 72.7633 - 28ms/epoch - 2ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 63.6652 - 28ms/epoch - 2ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 53.2872 - 29ms/epoch - 2ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 46.6297 - 29ms/epoch - 2ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 41.9179 - 29ms/epoch - 2ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 39.5882 - 36ms/epoch - 3ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 36.4862 - 25ms/epoch - 2ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 32.7335 - 29ms/epoch - 2ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 30.7049 - 27ms/epoch - 2ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 29.4039 - 27ms/epoch - 2ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 29.0209 - 28ms/epoch - 2ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 27.3468 - 27ms/epoch - 2ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 26.6800 - 27ms/epoch - 2ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 26.1067 - 25ms/epoch - 2ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 26.4086 - 25ms/epoch - 2ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 26.6238 - 26ms/epoch - 2ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 25.9850 - 24ms/epoch - 2ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 24.2930 - 26ms/epoch - 2ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 24.4071 - 26ms/epoch - 2ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 25.2323 - 27ms/epoch - 2ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 24.4132 - 27ms/epoch - 2ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 23.2640 - 26ms/epoch - 2ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 23.1279 - 28ms/epoch - 2ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 22.6991 - 28ms/epoch - 2ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 23.0848 - 28ms/epoch - 2ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 23.2121 - 30ms/epoch - 2ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 22.4114 - 30ms/epoch - 2ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 22.3079 - 35ms/epoch - 3ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 21.9329 - 31ms/epoch - 2ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 21.8370 - 34ms/epoch - 3ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 21.7040 - 32ms/epoch - 2ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 21.7848 - 31ms/epoch - 2ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 21.2049 - 29ms/epoch - 2ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 21.1679 - 30ms/epoch - 2ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 21.2507 - 36ms/epoch - 3ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 20.9410 - 32ms/epoch - 2ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 20.8481 - 27ms/epoch - 2ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 20.7710 - 28ms/epoch - 2ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 21.8591 - 32ms/epoch - 2ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 21.0290 - 30ms/epoch - 2ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 20.5515 - 29ms/epoch - 2ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 20.2929 - 30ms/epoch - 2ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 20.5508 - 35ms/epoch - 3ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 20.2041 - 32ms/epoch - 2ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 19.9925 - 30ms/epoch - 2ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 19.6564 - 30ms/epoch - 2ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 19.4719 - 31ms/epoch - 2ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 19.8257 - 33ms/epoch - 3ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 19.2746 - 30ms/epoch - 2ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 19.8620 - 33ms/epoch - 3ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 21.4442 - 30ms/epoch - 2ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 19.8787 - 31ms/epoch - 2ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 19.2989 - 28ms/epoch - 2ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 18.8874 - 33ms/epoch - 3ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 18.6819 - 33ms/epoch - 3ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 18.5219 - 28ms/epoch - 2ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 18.3686 - 28ms/epoch - 2ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 18.1724 - 28ms/epoch - 2ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 18.4216 - 26ms/epoch - 2ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 18.4465 - 26ms/epoch - 2ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 17.8236 - 29ms/epoch - 2ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 19.9776 - 26ms/epoch - 2ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 19.3199 - 27ms/epoch - 2ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 18.9112 - 28ms/epoch - 2ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 17.6331 - 27ms/epoch - 2ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 17.9398 - 26ms/epoch - 2ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 17.3411 - 29ms/epoch - 2ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 17.2189 - 28ms/epoch - 2ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 17.2072 - 26ms/epoch - 2ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 18.4926 - 26ms/epoch - 2ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 16.9207 - 26ms/epoch - 2ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 16.5320 - 28ms/epoch - 2ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 16.5094 - 27ms/epoch - 2ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 16.6133 - 27ms/epoch - 2ms/step
# Antes de Guardar el (RMSE): 4.096458657364227

# %% [markdown]
# El siguiente código configura una red neuronal y lee los datos (para predicciones), pero no borra el directorio del modelo ni se ajusta a la red neuronal. Se utilizan los pesos del ajuste anterior.

# %% [markdown]
# Ahora recargamos la red y realizamos otra predicción. El RMSE debería coincidir exactamente con el anterior si la red neuronal realmente se guardó y recargó.

# %%
from tensorflow.keras.models import load_model
model2 = load_model(os.path.join(save_path,"network.h5"))
pred = model2.predict(x)
# RMSE error.
score = np.sqrt(metrics.mean_squared_error(pred,y))
print(f"Despues de cargar el modelo (RMSE): {score}")
# Out:
# Despues de cargar el modelo (RMSE): 4.096458657364227
